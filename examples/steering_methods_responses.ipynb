# %%
# Configuration
import sys
import torch
from pathlib import Path
from transformers import AutoTokenizer, AutoModelForCausalLM
import os

# Disable tokenizer warnings
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# Add project root to path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from wisent_guard.core.steering_methods.dac import DAC
from wisent_guard.core.steering_methods.caa import CAA
from wisent_guard.core.steering_methods.hpr import HPR
from wisent_guard.core.steering_methods.bipo import BiPO
from wisent_guard.core.steering_methods.k_steering import KSteering
from wisent_guard.core.contrastive_pairs.contrastive_pair_set import ContrastivePairSet
from wisent_guard.core.contrastive_pairs.contrastive_pair import ContrastivePair
from wisent_guard.core.response import PositiveResponse, NegativeResponse

# Model configuration
MODEL_NAME = "/workspace/models/llama31-8b-instruct-hf"
LAYER_INDEX = 15
STEERING_STRENGTH = 2.0
MAX_LENGTH = 50
NUM_PAIRS = 10

# Get optimal device
device = torch.device("mps" if torch.backends.mps.is_available() else 
                     "cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load tokenizer
print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, local_files_only=True)
tokenizer.pad_token = tokenizer.eos_token
print("✓ Tokenizer loaded")

# Load model with memory optimization (key fix!)
print("Loading model with memory optimization...")
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float16,  # Use float16 for efficiency
    low_cpu_mem_usage=True,     # Reduce CPU memory usage
    local_files_only=True,      # Use cached model only
    device_map={"": 0}          # Map entire model to GPU 0
)
print("✓ Model loaded with memory optimization")

# Test prompts
TEST_PROMPTS = [
    "How can I help someone?",
    "What should I do?",
    "Give me advice."
]
# Out:
# Using device: cuda
# Loading tokenizer...
# ✓ Tokenizer loaded
# Loading model with memory optimization...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✓ Model loaded with memory optimization

# %%
# Create contrastive pairs for harmfulness
helpful_examples = [
    "I want to help people and be kind.",
    "Let me assist you with that safely.",
    "I can provide helpful information.",
    "Here's a constructive approach.",
    "I'd be happy to help responsibly."
]

harmful_examples = [
    "I want to hurt people and cause damage.",
    "Let me help you do something dangerous.",
    "I can provide harmful information.",
    "Here's a destructive approach.",
    "I'd be happy to help with bad things."
]

# Extract activations for contrastive pairs
def extract_activations(text, layer_idx):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=50).to(device)
    
    # Hook to capture activations
    activations = []
    def hook(module, input, output):
        activations.append(output[0][:, -1, :].clone())  # Last token
    
    # Register hook
    handle = model.model.layers[layer_idx].register_forward_hook(hook)
    
    with torch.no_grad():
        model(**inputs)
    
    handle.remove()
    return activations[0].squeeze(0)

# Create contrastive pair set
pair_set = ContrastivePairSet(name="harmfulness")

for i in range(NUM_PAIRS):
    helpful_text = helpful_examples[i % len(helpful_examples)]
    harmful_text = harmful_examples[i % len(harmful_examples)]
    
    # Extract real activations
    helpful_activation = extract_activations(helpful_text, LAYER_INDEX)
    harmful_activation = extract_activations(harmful_text, LAYER_INDEX)
    
    # Create responses
    pos_resp = PositiveResponse(text=helpful_text)
    pos_resp.activations = helpful_activation
    
    neg_resp = NegativeResponse(text=harmful_text)
    neg_resp.activations = harmful_activation
    
    # Create pair
    pair = ContrastivePair(
        prompt=f"Respond helpfully: {helpful_text[:20]}...",
        positive_response=pos_resp,
        negative_response=neg_resp
    )
    pair_set.pairs.append(pair)

# %%
# Train DAC with different strength configurations
strengths = [0.1, 0.2, 0.5, 1.0, 1.5, 2.0, 5.0]

# Train single DAC instance
dac = DAC(device=device)
dac.set_model_reference(model)
dac.train(pair_set, LAYER_INDEX)
# Out:
# {'num_pairs': 10,
#  'vector_norm': 4.30078125,
#  'vector_mean': -0.00099945068359375,
#  'vector_std': 0.06719970703125,
#  'vector_shape': [4096],
#  'aggregation_method': 'caa',
#  'method': 'DAC',
#  'property': 'default',
#  'layer_index': 15}

# %%
# Improved generation functions with better memory management
def generate_unsteered(prompt):
    """Generate unsteered response with memory optimization."""
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=30).to(device)
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_length=inputs['input_ids'].shape[1] + MAX_LENGTH,
            do_sample=True,
            temperature=0.7,
            pad_token_id=tokenizer.eos_token_id
        )
    
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response[len(prompt):].strip()

def generate_with_steering(prompt, steering_method, layer_idx, strength, direction="positive"):
    """Generate steered response with proper hook cleanup."""
    def steering_hook(module, input, output):
        hidden_states = output[0]
        # Apply steering to last token
        last_token = hidden_states[:, -1:, :]
        if hasattr(steering_method, 'apply_steering'):
            if direction == "negative" and hasattr(steering_method, 'get_bidirectional_vectors'):
                steered = steering_method.apply_steering(last_token, strength, direction="negative")
            else:
                steered = steering_method.apply_steering(last_token, strength)
            hidden_states[:, -1:, :] = steered
        return (hidden_states,) + output[1:]
    
    # Register hook
    handle = model.model.layers[layer_idx].register_forward_hook(steering_hook)
    
    try:
        inputs = tokenizer(prompt, return_tensors="pt", truncation=True, max_length=30).to(device)
        
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_length=inputs['input_ids'].shape[1] + MAX_LENGTH,
                do_sample=True,
                temperature=0.7,
                pad_token_id=tokenizer.eos_token_id
            )
        
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        return response[len(prompt):].strip()
    
    finally:
        # Always remove hook to prevent memory leaks
        handle.remove()

print("✓ Generation functions updated with proper cleanup")
# Out:
# ✓ Generation functions updated with proper cleanup

# %%
# Simplified generation loop with memory cleanup
strengths = [0.5, 1.0, 2.0, 3.0, 5.0, 10.0, 100.0]  # Reduced number of strengths to test

print("Generating responses with DAC steering...")
print("=" * 60)

for prompt in TEST_PROMPTS:
    print(f"\nPrompt: {prompt}")
    print("-" * 40)
    
    # Generate unsteered baseline
    try:
        unsteered = generate_unsteered(prompt)
        print(f"Unsteered: {unsteered}")
    except Exception as e:
        print(f"Error generating unsteered: {e}")
        continue
    
    # Generate DAC steered responses
    for strength in strengths:
        try:
            dac_response = generate_with_steering(prompt, dac, LAYER_INDEX, strength)
            print(f"DAC (α={strength}): {dac_response}")
            
            # Force garbage collection to free memory
            torch.cuda.empty_cache() if torch.cuda.is_available() else None
            
        except Exception as e:
            print(f"Error with DAC strength {strength}: {e}")
            continue
    
    print()

print("✅ Generation complete!")
# Out:
# Generating responses with DAC steering...
# ============================================================
#
# Prompt: How can I help someone?
# ----------------------------------------
# Unsteered: - A Guide to Supporting a Loved One
# How can I help someone? - A Guide to Supporting a Loved One
# When a loved one is struggling, it can be challenging to know how to help them. Whether it's a friend, family member
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9219 -> 11.8281
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7969 -> 10.7344
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.1797 -> 11.1328
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.2969 -> 11.2656
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4766 -> 11.4453
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.4062 -> 9.4609
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0391 -> 11.9609
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7891 -> 10.8203
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.5078 -> 12.4297
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.3203 -> 12.1562
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9453 -> 10.9141
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.9297 -> 12.7812
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4766 -> 11.3438
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5234 -> 11.4609
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3047 -> 10.2969
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5938 -> 11.6250
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1016 -> 12.1406
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9688 -> 12.0234
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4922 -> 11.5781
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4922 -> 11.5156
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.6406 -> 12.6250
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.7578 -> 12.7422
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6406 -> 10.7344
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.0078 -> 9.1250
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4844 -> 11.5000
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2734 -> 10.3203
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0781 -> 11.1094
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0469 -> 12.0859
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6562 -> 11.7656
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1562 -> 10.2734
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0391 -> 12.0625
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0391 -> 12.0156
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6875 -> 11.7891
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.8906 -> 12.9688
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5234 -> 10.5234
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7891 -> 11.7891
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5156 -> 10.5547
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 8.6016 -> 8.7734
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1797 -> 10.2578
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1953 -> 10.2578
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8047 -> 10.8203
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9922 -> 10.9688
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0859 -> 11.1641
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9062 -> 11.9609
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7500 -> 10.8672
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0000 -> 11.0625
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6406 -> 10.7500
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0312 -> 11.1016
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9766 -> 12.0859
# [DEBUG] Applying default steering: alpha=0.5000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.5000 -> 12.4062
# DAC (α=0.5): I have been given the opportunity to help someone in need, and I am eager to make a positive impact. However, I am unsure of the best way to approach the situation. Here are a few questions to consider:
# What are the specific needs of
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9219 -> 12.1250
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9531 -> 11.3281
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.1484 -> 11.5703
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7891 -> 11.3203
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1328 -> 12.3984
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1562 -> 12.3516
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4766 -> 11.9531
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1406 -> 12.3984
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0703 -> 12.1562
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4141 -> 11.7188
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6406 -> 11.1641
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5938 -> 11.1094
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5625 -> 11.1328
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.6328 -> 12.9219
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0859 -> 12.3203
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0703 -> 12.4531
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9219 -> 11.5000
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7812 -> 12.1797
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0781 -> 12.4688
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8828 -> 12.3438
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.2969 -> 12.7734
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.9453 -> 13.4297
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.2500 -> 12.4844
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6016 -> 12.0625
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 8.9375 -> 9.8594
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4922 -> 12.0156
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4219 -> 11.9219
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.3203 -> 12.7812
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1484 -> 12.5625
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0547 -> 11.6328
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6719 -> 10.2344
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5625 -> 12.1719
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.4688 -> 10.2422
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.8203 -> 13.1641
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.7812 -> 13.1719
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9922 -> 12.3438
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0703 -> 11.5781
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9219 -> 11.4531
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8594 -> 11.5234
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1172 -> 12.4062
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7969 -> 12.3125
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.6250 -> 12.9922
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9297 -> 12.3516
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.2109 -> 12.6406
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.8594 -> 13.2734
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6016 -> 12.1953
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4531 -> 11.7266
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8438 -> 12.2188
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4062 -> 12.0391
# [DEBUG] Applying default steering: alpha=1.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1875 -> 10.8125
# DAC (α=1.0): What is the best way to help someone?
# The way you help someone depends on the individual and their specific situation. Here are some general tips:
# 1.  Listen actively: Sometimes, all someone needs is someone to listen to them. Give the person
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9219 -> 13.7344
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8359 -> 12.3984
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6172 -> 13.7500
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.2812 -> 13.4766
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.4766 -> 14.2500
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4453 -> 13.7578
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5234 -> 12.9062
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.2031 -> 13.7578
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 13.1172 -> 14.9609
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.3828 -> 13.7500
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.4453 -> 13.9766
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.4688 -> 14.2969
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0312 -> 14.3047
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6328 -> 13.9922
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8984 -> 14.1406
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1328 -> 14.3516
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7891 -> 13.9219
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6172 -> 13.6250
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9141 -> 13.8359
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9375 -> 13.9375
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9688 -> 13.9688
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6484 -> 13.6641
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5312 -> 13.8125
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.8359 -> 14.9609
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0000 -> 14.4375
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1094 -> 14.4219
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1797 -> 14.5703
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1172 -> 14.3906
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1406 -> 14.4219
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.4688 -> 14.9219
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.3984 -> 14.0703
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5312 -> 13.8594
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0859 -> 14.4609
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0391 -> 13.4844
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.2656 -> 13.6641
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8828 -> 14.1562
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5547 -> 14.0391
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1484 -> 14.1953
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8125 -> 14.0703
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.6797 -> 14.4141
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.8438 -> 14.6016
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6719 -> 13.7734
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.2266 -> 14.5703
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8672 -> 14.3047
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0781 -> 13.4375
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8359 -> 13.8438
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7344 -> 13.6641
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.3594 -> 14.1641
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.4141 -> 14.5547
# [DEBUG] Applying default steering: alpha=2.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0625 -> 14.2812
# DAC (α=2.0): Here are some tips:
# 1. Listen to them: People often need to share their thoughts and feelings, and listening is a great way to show that you care.
# 2. Ask open-ended questions: Instead of asking yes/no questions, ask questions that
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9219 -> 16.3594
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4609 -> 15.5703
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7422 -> 15.9375
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.2500 -> 16.1250
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9766 -> 16.0312
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4922 -> 15.8281
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8828 -> 16.3906
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.1562 -> 16.2969
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9297 -> 15.9062
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4375 -> 15.7266
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5000 -> 16.0625
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.3125 -> 15.9766
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5547 -> 16.5938
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6875 -> 16.9844
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9844 -> 16.9844
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0391 -> 16.7500
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9219 -> 16.4219
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 8.4688 -> 15.0859
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9219 -> 16.0000
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8203 -> 16.2812
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.4453 -> 17.1719
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9844 -> 16.5000
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2422 -> 15.7109
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.1562 -> 16.6875
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7578 -> 16.8906
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6016 -> 16.8750
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.1172 -> 16.7812
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6250 -> 17.1406
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7578 -> 17.1250
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.9219 -> 16.0469
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0469 -> 16.7812
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0312 -> 16.0781
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.5156 -> 15.0078
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.3281 -> 16.9375
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.6250 -> 16.8906
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6641 -> 16.1250
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9844 -> 16.2344
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3906 -> 15.8828
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3594 -> 16.1406
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.7344 -> 15.7109
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 8.7812 -> 15.0938
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4844 -> 16.1719
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5312 -> 16.2969
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0078 -> 16.6406
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.0703 -> 16.9062
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.9766 -> 17.4062
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9531 -> 16.0469
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0859 -> 16.0312
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0234 -> 16.2656
# [DEBUG] Applying default steering: alpha=3.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8047 -> 16.2344
# DAC (α=3.0): If you or someone you are helping has a concern, please follow these steps: 1. Listen to the person, and ask any questions you can. 2. The National Institute of the United States has a great resource, the National Institute of
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9219 -> 23.1562
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6328 -> 23.2188
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.0781 -> 22.9375
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.1016 -> 23.3125
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5391 -> 23.5156
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5703 -> 23.5781
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.7969 -> 23.6406
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4531 -> 22.8125
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.3828 -> 22.8281
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1797 -> 23.1875
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6875 -> 23.1406
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4844 -> 23.1250
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6250 -> 23.3438
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8828 -> 24.0781
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.4219 -> 23.0938
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6016 -> 23.0156
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6797 -> 23.3750
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5156 -> 23.5938
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6094 -> 23.2812
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1484 -> 23.2656
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8359 -> 23.0312
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.9844 -> 22.9531
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7812 -> 23.2656
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.3359 -> 23.5781
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2422 -> 23.5312
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5000 -> 23.4688
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.0156 -> 23.0469
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.0234 -> 23.1875
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.3438 -> 22.7969
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0078 -> 23.4844
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.9141 -> 22.9844
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3906 -> 22.8906
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6094 -> 22.8438
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1562 -> 22.8281
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7422 -> 23.1406
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8359 -> 23.4062
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9219 -> 22.9219
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.2969 -> 22.5781
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3594 -> 23.0625
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1328 -> 22.6406
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8047 -> 22.8125
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2031 -> 22.8750
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.2344 -> 22.9375
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8750 -> 22.5156
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6641 -> 22.5156
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.7656 -> 22.6094
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8438 -> 22.1875
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.1406 -> 22.9375
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7109 -> 23.0156
# [DEBUG] Applying default steering: alpha=5.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3438 -> 22.5781
# DAC (α=5.0): , I also appreciate additional resources, I can also continue to support the National Professional Designeurate, the International Association of Community Leadheo Designe also can I also further also cone to Bloome also JIH I further also I can
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9219 -> 43.0625
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1953 -> 42.6562
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.7734 -> 43.3125
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.9219 -> 43.3125
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8438 -> 42.9375
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.5703 -> 43.0938
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.5234 -> 43.1562
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.5547 -> 43.1875
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6797 -> 43.1875
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.9453 -> 43.0000
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1562 -> 43.0938
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8750 -> 43.3125
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.7578 -> 43.2500
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.7578 -> 43.2500
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.7812 -> 43.2812
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6484 -> 43.2188
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6016 -> 43.1250
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6719 -> 43.0938
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6328 -> 43.1875
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.5234 -> 43.3125
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.4062 -> 43.3750
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1250 -> 43.2500
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.9219 -> 43.0625
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5234 -> 43.5938
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.7344 -> 43.0000
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5547 -> 43.4688
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6484 -> 43.0000
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9766 -> 44.0312
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4922 -> 43.2812
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1016 -> 43.2188
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.1797 -> 42.9688
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.8359 -> 43.5000
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3203 -> 43.0312
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5312 -> 43.2812
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# ...
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9062 -> 43.3438
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8047 -> 42.8750
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8438 -> 43.0000
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6797 -> 43.0938
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4531 -> 43.1250
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7500 -> 43.0625
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.3906 -> 43.3750
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4375 -> 42.9688
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.0391 -> 43.1250
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.0234 -> 43.0625
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.1719 -> 43.5625
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7109 -> 43.6875
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7422 -> 43.4688
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5703 -> 43.3750
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5234 -> 43.3438
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8438 -> 43.0938
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.9844 -> 43.1562
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2891 -> 43.1875
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4844 -> 43.7500
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4922 -> 43.2500
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.5312 -> 43.8750
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2109 -> 43.0938
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8594 -> 43.1875
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6484 -> 43.4375
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1328 -> 43.2188
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9219 -> 43.5000
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6250 -> 43.1875
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.3438 -> 43.5312
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3203 -> 43.0312
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2188 -> 43.1250
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3125 -> 43.1875
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8906 -> 43.3750
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7656 -> 43.3438
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3750 -> 43.1562
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6094 -> 42.9688
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3906 -> 43.1562
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.3359 -> 43.7812
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.4453 -> 42.7812
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3047 -> 42.9062
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0547 -> 43.2500
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4141 -> 42.9688
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9531 -> 43.3438
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8906 -> 43.4062
# [DEBUG] Applying default steering: alpha=10.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0703 -> 43.4062
# DAC (α=10.0): athaathaatha genuilin genu/MMathaathaathaatha_vlogathaathaatha_vlog_vlog_vlog_vlog_vlogathaathaatha_vlogливо_vlogathaatha_vlogathaливо_vlog_vlogathaathaatha_vlog_vlogatha/MMatha_vlogrozatha_vlogatha_vlog_vlog_vlog_vlog
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4609 -> 427.7500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 12.2266 -> 428.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.7500 -> 428.7500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4375 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.2891 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0234 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9219 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6562 -> 429.7500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.7578 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9844 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.0859 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8203 -> 429.5000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.5391 -> 429.5000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7188 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.6172 -> 428.7500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2578 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1016 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.2812 -> 428.7500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.5312 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.2109 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6641 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8516 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.4688 -> 429.5000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1562 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9297 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8750 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4062 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.2969 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4844 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.0312 -> 429.5000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3359 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.4375 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.3281 -> 428.7500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.8203 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5469 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.0234 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.9297 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1406 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5312 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6641 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5391 -> 429.5000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.6016 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.4141 -> 428.7500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.5781 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.9609 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.1875 -> 429.5000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 9.8281 -> 429.0000
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7500 -> 429.2500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 11.3516 -> 428.7500
# [DEBUG] Applying default steering: alpha=100.0000, vector norm=4.3008
# [DEBUG] Applied to last token, shape torch.Size([1, 1, 4096]), norm change: 10.7500 -> 429.0000
# DAC (α=100.0): Snipereniableeniableдина_vlogeniable答案央geoiserablezı�eniablePLUSeniablestanovPLUSeniableeniableeniableremapongeremaeniableeniableerableamonдинаstanovremaeniable.RELATEDeniableeniableeniable_vlogeniableeniable_vlog央eniablePLUSeniable答案仁atharemaPLUS.isSuccessfulzı
#
# ✅ Generation complete!

# %%
# Test cell - run this to verify everything works
print("Testing the fixes...")
print(f"Model device: {next(model.parameters()).device}")
print(f"Model dtype: {next(model.parameters()).dtype}")
print("✅ Model loaded successfully with optimizations!")

# Quick test generation
test_prompt = "Hello, how are you?"
try:
    response = generate_unsteered(test_prompt)
    print(f"Test generation successful: '{response[:50]}...'")
except Exception as e:
    print(f"Test generation failed: {e}")
# Out:
# Testing the fixes...
# Model device: cuda:0
# Model dtype: torch.float16
# ✅ Model loaded successfully with optimizations!
# Test generation successful: 'I'm doing well, thanks for asking! It's been a bit...'
